# %%
words={'madad':'help',
       'kursi':'chair',    #creating a dictionary of hindi words with their english translation
       'billi':'cat',
       'insan':'human'}
word=input('enter the word you want meaning of:')
print(words[word])
# Out:
# enter the word you want meaning of:kursi
# chair

# %%
s=set()
n=int(input('enter no 1:'))
s.add(n)
n=int(input('enter no 2:'))
s.add(n)
n=int(input('enter no 3:'))
s.add(n)
n=int(input('enter no 4:'))
s.add(n)
n=int(input('enter no 5:'))
s.add(n)
print(s)
# Out:
# enter no 1:10
# enter no 2:0
# enter no 3:21
# enter no 4:10
# enter no 5:30
# {0, 10, 21, 30}

# %%
# create an empty dict and allow  user to enter 5 different songs as value and users name as key. assume that key value pair is unique.
d={} # empty dict
name=input('enter your name:') # enter name as key
song=input('enter your favourite song:') # enter song as value
d.update({name:song}) # this command is used to add new key vlaue pairs to an empty dict= dictname.update({key:value})
name=input('enter your name:')
song=input('enter your favourite song:')
d.update({name:song})
name=input('enter your name:')
song=input('enter your favourite song:')
d.update({name:song})
name=input('enter your name:')
song=input('enter your favourite song:')
d.update({name:song})
name=input('enter your name:')
song=input('enter your favourite song:')
d.update({name:song})
print(d)
# Out:
# enter your name:rohan
# enter your favourite song:5
# enter your name:rohan6
# enter your favourite song:6
# enter your name:rohan
# enter your favourite song:4
# enter your name:rohan
# enter your favourite song:3
# enter your name:rohan
# enter your favourite song:1
# {'rohan': '1', 'rohan6': '6'}
